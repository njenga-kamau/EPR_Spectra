# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestRegressor

# %%
one_um_0Gy_df = pd.read_csv('/Users/njengamacbook/Downloads/OneDrive_1_6-19-2024/1um_0Gy_Gain1.csv')

one_um_0Gy_df
# Out:
#             X [G]   Intensity
# 0     2508.969971  594.879395
# 1     2509.947021  591.879395
# 2     2510.924072  589.879395
# 3     2511.901123  589.879395
# 4     2512.878174  586.879395
# ...           ...         ...
# 2043  4505.062012 -305.120605
# 2044  4506.039063 -305.120605
# 2045  4507.016113 -301.120605
# 2046  4507.993164 -301.120605
# 2047  4508.970215 -301.120605
#
# [2048 rows x 2 columns]

# %%
one_um_4Gy = pd.read_csv('/Users/njengamacbook/Downloads/OneDrive_1_6-19-2024/1um_4Gy_Gain1B.csv')

one_um_4Gy
# Out:
#             X [G]  Intensity
# 0     2508.969971  587.55957
# 1     2509.947021  587.55957
# 2     2510.924072  587.55957
# 3     2511.901123  587.55957
# 4     2512.878174  587.55957
# ...           ...        ...
# 2043  4505.062012 -309.44043
# 2044  4506.039063 -306.44043
# 2045  4507.016113 -305.44043
# 2046  4507.993164 -304.44043
# 2047  4508.970215 -301.44043
#
# [2048 rows x 2 columns]

# %%
import pandas as pd
fifty_0Gy_C = pd.read_csv('/Users/njengamacbook/Downloads/OneDrive_1_6-19-2024/50nm_0Gy_control.csv')

fifty_0Gy_C
# Out:
#             X [G]   Intensity
# 0     2508.969971  135.160645
# 1     2509.947021  138.160645
# 2     2510.924072  136.160645
# 3     2511.901123  135.160645
# 4     2512.878174  135.160645
# ...           ...         ...
# 2043  4505.062012 -115.839355
# 2044  4506.039063 -114.839355
# 2045  4507.016113 -115.839355
# 2046  4507.993164 -115.839355
# 2047  4508.970215 -114.839355
#
# [2048 rows x 2 columns]

# %%
fifty_0Gy_IR = pd.read_csv('/Users/njengamacbook/Downloads/OneDrive_1_6-19-2024/50nm_0Gy_IR.csv')

fifty_0Gy_IR
# Out:
#             X [G]   Intensity
# 0     2508.969971  178.816895
# 1     2509.947021  177.816895
# 2     2510.924072  179.816895
# 3     2511.901123  181.816895
# 4     2512.878174  182.816895
# ...           ...         ...
# 2043  4505.062012 -107.183105
# 2044  4506.039063 -104.183105
# 2045  4507.016113 -102.183105
# 2046  4507.993164 -100.183105
# 2047  4508.970215  -99.183105
#
# [2048 rows x 2 columns]

# %%
onefifty_0Gy = pd.read_csv('/Users/njengamacbook/Downloads/OneDrive_1_6-19-2024/150nm_0Gy_Gain5.csv')

onefifty_0Gy
# Out:
#             X [G]   Intensity
# 0     2508.969971  477.361328
# 1     2509.947021  477.361328
# 2     2510.924072  477.361328
# 3     2511.901123  476.361328
# 4     2512.878174  474.361328
# ...           ...         ...
# 2043  4505.062012 -200.638672
# 2044  4506.039063 -194.638672
# 2045  4507.016113 -190.638672
# 2046  4507.993164 -188.638672
# 2047  4508.970215 -186.638672
#
# [2048 rows x 2 columns]

# %%
onefifty_4Gy = pd.read_csv('/Users/njengamacbook/Downloads/OneDrive_1_6-19-2024/150nm_4Gy_Gain5.csv')

onefifty_4Gy
# Out:
#             X [G]   Intensity
# 0     2508.969971  629.077148
# 1     2509.947021  630.077148
# 2     2510.924072  629.077148
# 3     2511.901123  629.077148
# 4     2512.878174  628.077148
# ...           ...         ...
# 2043  4505.062012 -333.922852
# 2044  4506.039063 -332.922852
# 2045  4507.016113 -331.922852
# 2046  4507.993164 -330.922852
# 2047  4508.970215 -330.922852
#
# [2048 rows x 2 columns]

# %%
fivehundred_0Gy = pd.read_csv('/Users/njengamacbook/Downloads/OneDrive_1_6-19-2024/500nm_0Gy_Gain2.csv')

fivehundred_0Gy
# Out:
#             X [G]   Intensity
# 0     2508.969971  455.525391
# 1     2509.947021  456.525391
# 2     2510.924072  457.525391
# 3     2511.901123  457.525391
# 4     2512.878174  459.525391
# ...           ...         ...
# 2043  4505.062012 -267.474609
# 2044  4506.039063 -264.474609
# 2045  4507.016113 -262.474609
# 2046  4507.993164 -261.474609
# 2047  4508.970215 -257.474609
#
# [2048 rows x 2 columns]

# %%
fivehundred_4Gy = pd.read_csv('/Users/njengamacbook/Downloads/OneDrive_1_6-19-2024/500nm_4Gy_Gain5B.csv')

fivehundred_4Gy
# Out:
#             X [G]   Intensity
# 0     2508.969971  404.451172
# 1     2509.947021  398.451172
# 2     2510.924072  392.451172
# 3     2511.901123  387.451172
# 4     2512.878174  382.451172
# ...           ...         ...
# 2043  4505.062012 -343.548828
# 2044  4506.039063 -342.548828
# 2045  4507.016113 -341.548828
# 2046  4507.993164 -339.548828
# 2047  4508.970215 -340.548828
#
# [2048 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
one_um_0Gy_df = pd.read_csv('/Users/njengamacbook/Downloads/OneDrive_1_6-19-2024/1um_0Gy_Gain1.csv')

x_values = one_um_0Gy_df['X [G]']
x_values

y_values = one_um_0Gy_df['Intensity']
y_values


plt.plot(x_values, y_values)

# Label the axes
plt.xlabel('X[G]')
plt.ylabel('Intensity')

# Add a title
plt.title('1uM 0Gy')

# Show the plot
plt.show()

# %%
one_um_4Gy = pd.read_csv('/Users/njengamacbook/Downloads/OneDrive_1_6-19-2024/1um_4Gy_Gain1B.csv')

x_values = one_um_4Gy['X [G]']
x_values

y_values = one_um_4Gy['Intensity']
y_values


plt.plot(x_values, y_values)

# Label the axes
plt.xlabel('X[G]')
plt.ylabel('Intensity')

# Add a title
plt.title('1uM 4Gy')

# Show the plot
plt.show()

# %%
fifty_0Gy_C = pd.read_csv('/Users/njengamacbook/Downloads/OneDrive_1_6-19-2024/50nm_0Gy_control.csv')

x_values = fifty_0Gy_C['X [G]']
x_values

y_values = fifty_0Gy_C['Intensity']
y_values


plt.plot(x_values, y_values)

# Label the axes
plt.xlabel('X[G]')
plt.ylabel('Intensity')

# Add a title
plt.title('50 nm 0Gy')

# Show the plot
plt.show()

# %%
fifty_0Gy_IR = pd.read_csv('/Users/njengamacbook/Downloads/OneDrive_1_6-19-2024/50nm_0Gy_IR.csv')

x_values = fifty_0Gy_IR['X [G]']
x_values

y_values = fifty_0Gy_IR['Intensity']
y_values


plt.plot(x_values, y_values)

# Label the axes
plt.xlabel('X[G]')
plt.ylabel('Intensity')

# Add a title
plt.title('50 nm 4Gy')

# Show the plot
plt.show()

# %%
onefifty_0Gy = pd.read_csv('/Users/njengamacbook/Downloads/OneDrive_1_6-19-2024/150nm_0Gy_Gain5.csv')

x_values = onefifty_0Gy['X [G]']
x_values

y_values = onefifty_0Gy['Intensity']
y_values


plt.plot(x_values, y_values)

# Label the axes
plt.xlabel('X[G]')
plt.ylabel('Intensity')

# Add a title
plt.title('150 nm 0Gy')

# Show the plot
plt.show()

# %%
onefifty_4Gy = pd.read_csv('/Users/njengamacbook/Downloads/OneDrive_1_6-19-2024/150nm_4Gy_Gain5.csv')

x_values = onefifty_4Gy['X [G]']
x_values

y_values = onefifty_4Gy['Intensity']
y_values


plt.plot(x_values, y_values)

# Label the axes
plt.xlabel('X[G]')
plt.ylabel('Intensity')

# Add a title
plt.title('150 nm 4Gy')

# Show the plot
plt.show()

# %%
fivehundred_0Gy = pd.read_csv('/Users/njengamacbook/Downloads/OneDrive_1_6-19-2024/500nm_0Gy_Gain2.csv')

x_values = fivehundred_0Gy['X [G]']
x_values

y_values = fivehundred_0Gy['Intensity']
y_values


plt.plot(x_values, y_values)

# Label the axes
plt.xlabel('X[G]')
plt.ylabel('Intensity')

# Add a title
plt.title('500 nm 0Gy')

# Show the plot
plt.show()

# %%
fivehundred_4Gy = pd.read_csv('/Users/njengamacbook/Downloads/OneDrive_1_6-19-2024/500nm_4Gy_Gain5B.csv')

x_values = fivehundred_4Gy['X [G]']
x_values

y_values = fivehundred_4Gy['Intensity']
y_values


plt.plot(x_values, y_values)

# Label the axes
plt.xlabel('X[G]')
plt.ylabel('Intensity')

# Add a title
plt.title('500 nm 4Gy')

# Show the plot
plt.show()

# %%
colors = ['red', 'blue']  # Adjust colors as needed

# Create the plot
plt.figure()  # Create a new figure

# Loop through DataFrames and plot with different colors
for i, df in enumerate( [one_um_0Gy_df, one_um_4Gy] ):
  x_data = df['X [G]']
  y_data = df['Intensity']
  plt.plot(x_data, y_data, label=f"DataFrame {i+1}", color=colors[i])  # Use index for label

# Label the axes and add a title
plt.xlabel('X[G]')
plt.ylabel('Intensity')
plt.title('1uM 0Gy vs 4Gy')

# Add legend
plt.legend()

# Show the plot
plt.show()

# %%
colors = ['red', 'blue']  # Adjust colors as needed

# Create the plot
plt.figure()  # Create a new figure

# Loop through DataFrames and plot with different colors
for i, df in enumerate( [fifty_0Gy_C, fifty_0Gy_IR] ):
  x_data = df['X [G]']
  y_data = df['Intensity']
  plt.plot(x_data, y_data, label=f"DataFrame {i+1}", color=colors[i])  # Use index for label

# Label the axes and add a title
plt.xlabel('X[G]')
plt.ylabel('Intensity')
plt.title('50 nM 0Gy vs 4Gy')

# Add legend
plt.legend()

# Show the plot
plt.show()

# %%
colors = ['red', 'blue']  # Adjust colors as needed

# Create the plot
plt.figure()  # Create a new figure

# Loop through DataFrames and plot with different colors
for i, df in enumerate( [onefifty_0Gy, onefifty_4Gy] ):
  x_data = df['X [G]']
  y_data = df['Intensity']
  plt.plot(x_data, y_data, label=f"DataFrame {i+1}", color=colors[i])  # Use index for label

# Label the axes and add a title
plt.xlabel('X[G]')
plt.ylabel('Intensity')
plt.title('150 nM 0Gy vs 4Gy')

# Add legend
plt.legend()

# Show the plot
plt.show()

# %%
colors = ['red', 'blue']  # Adjust colors as needed

# Create the plot
plt.figure()  # Create a new figure

# Loop through DataFrames and plot with different colors
for i, df in enumerate( [fivehundred_0Gy, fivehundred_4Gy] ):
  x_data = df['X [G]']
  y_data = df['Intensity']
  plt.plot(x_data, y_data, label=f"DataFrame {i+1}", color=colors[i])  # Use index for label

# Label the axes and add a title
plt.xlabel('X[G]')
plt.ylabel('Intensity')
plt.title('500 nM 0Gy vs 4Gy')

# Add legend
plt.legend()

# Show the plot
plt.show()
